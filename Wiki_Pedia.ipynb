# %%
import requests

endpoint = "https://en.wikipedia.org/w/api.php"
params = {
    "action": "query",
    "format": "json",
    "prop": "extracts",
    "exintro": True,
    "explaintext": True,
    "titles": "2023_Cricket_World_Cup"
}

response = requests.get(endpoint, params=params)
data = response.json()
page_data = data["query"]["pages"]
page_id = list(page_data.keys())[0]
page_info = page_data[page_id]
page_title = page_info["title"]
page_extract = page_info["extract"]

print(f"Title: {page_title}")
print(f"Extract:\n{page_extract}")

# %%
import requests

endpoint = "https://en.wikipedia.org/w/api.php"
params = {
    "action": "query",
    "format": "json",
    "prop": "categories",
    "titles": "2023_Cricket_World_Cup"
}

response = requests.get(endpoint, params=params)
data = response.json()

page_data = data["query"]["pages"]
page_id = list(page_data.keys())[0]
page_info = page_data[page_id]
categories = page_info.get("categories", [])

category_names = [category["title"] for category in categories]

print(f"Categories: {', '.join(category_names)}")

# %%
import requests
import pandas as pd

endpoint = "https://en.wikipedia.org/w/api.php"
params = {
    "action": "query",
    "format": "json",
    "prop": "pageviews",
    "titles": "Lakshadweep",
    "pvipdays": 10  # Number of days for which you want pageview data
}

response = requests.get(endpoint, params=params)
data = response.json()

page_data = data["query"]["pages"]
page_id = list(page_data.keys())[0]
page_info = page_data[page_id]
page_title = page_info["title"]
page_views = page_info["pageviews"]

# Create a DataFrame from the pageviews data
df = pd.DataFrame(list(page_views.items()), columns=["Date", "Pageviews"])

# Convert the 'Date' column to datetime format
df["Date"] = pd.to_datetime(df["Date"])

df

# %%
import requests

endpoint = "https://en.wikipedia.org/w/api.php"
params = {
    "action": "sitematrix",
    "format": "json"
}

response = requests.get(endpoint, params=params)
data = response.json()

language_data = data["sitematrix"]["count"]

print(f"Number of Languages: {language_data}")

# %%
import requests

search_term = "domestic violence"

endpoint = "https://en.wikipedia.org/w/api.php"
params = {
    "action": "query",
    "format": "json",
    "list": "search",
    "srsearch": search_term
}

response = requests.get(endpoint, params=params)
data = response.json()

search_results = data["query"]["search"]

print("Wikipedia pages related to 'domestic violence':")
for result in search_results:
    page_title = result["title"]
    print(page_title)

# %%
import requests

search_term = "domestic violence"

endpoint = "https://en.wikipedia.org/w/api.php"
params = {
    "action": "query",
    "format": "json",
    "list": "search",
    "srsearch": search_term,
    "srprop": "totalhits"
}

response = requests.get(endpoint, params=params)
data = response.json()

total_hits = data["query"]["searchinfo"]["totalhits"]

print(f"Number of Wikipedia pages related to '{search_term}': {total_hits}")
